# %%
# read the table 
import pandas as pd
import numpy as np
df = pd.read_csv("data.csv")
print(df.shape)
# Out:
# (1062, 12)

# %%
# random sample 
df.sample(10)
# Out:
#                                       Faculty                     Full Name  \
# 818              Кафедра теоретической физики                           NaN
# 932               Кафедра прикладной механики                           NaN
# 149                 Кафедра высшей математики    Умнов Александр Евгеньевич
# 1028  Кафедра физического воспитания и спорта                           NaN
# 189                      Кафедра общей физики  Bulygin Vladimir Semyonovich
# 804              Кафедра теоретической физики                           NaN
# 242                      Кафедра общей физики      Kozlov Vitaly Fedorovich
# 877            Кафедра теоретической механики     Трухан Надежда Михайловна
# 633                Кафедра иностранных языков   Фельснер Ирина Вячеславовна
# 277                      Кафедра общей физики      Мирончук Елена Сергеевна
#
#          Date of Birth                                         Alma mater  \
# ...

# %%
# sample of the teacher 
display(df.iloc[891])
# Out:
# Faculty                       Кафедра радиотехники и телекоммуникаций
# Full Name                                     Арумов Георгий Петрович
# Date of Birth                                                     NaN
# Alma mater                                                        NaN
# Academic degree                                                   NaN
# Works               Department of Radio Engineering and Telecommun...
# Leads                            Laboratory work on radio engineering
# Knowledge                                                    4.83 (6)
# Ability to teach                                             4.25 (4)
# In communication                                             4.00 (7)
# Free                                                         3.67 (6)
# Overall score                                                4.00 (5)
# Name: 891, dtype: object
